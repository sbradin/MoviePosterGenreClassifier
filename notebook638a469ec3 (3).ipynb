# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv) 
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Conv2D,MaxPool2D,Dense,Flatten,BatchNormalization,Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import to_categorical
from keras.preprocessing import image 
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split 
from tensorflow.keras.applications import ResNet50 
from keras.regularizers import l2 
from keras.callbacks import EarlyStopping


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        os.path.join(dirname, filename) 
        


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session 

data = pd.read_csv('../input/movie-classifier/Multi_Label_dataset/train.csv')
data = data.head(2000)  

#isolate images and hotcode data
train_image = [] 
train_hot = [] 
listofHots = data.drop(['Id','Genre'],axis=1)
for i in range(data.shape[0]): 
    img = image.load_img('/kaggle/input/movie-classifier/Multi_Label_dataset/Images/'+
                         data['Id'][i]+
                         '.jpg',
                         target_size=(475,300,3))
    img = image.img_to_array(img)
    train_image.append(img) 
    train_hot.append(data['Id'][i])

x = np.array(train_image)
y = np.array(data.drop(['Id', 'Genre'],axis=1))

#test display
#random_image = np.random.randint(len(y))
#plt.imshow(train_image[0])
#plt.show() 

#make train/test variables
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1)  

#ResNet50_model2 = ResNet50(weights='imagenet', input_shape=(475, 300, 3), include_top=False) 
#x_train_FE = tf.keras.layers.Flatten()(ResNet50_model2.predict(x_train))
#x_test_FE = tf.keras.layers.Flatten()(ResNet50_model2.predict(x_test))

model = Sequential() 
model.add(Conv2D(32, (3,3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.1)) 
model.add(Conv2D(128, (3,3), activation='relu')) 
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))
model.add(Flatten()) 
model.add(Dense(128, activation='relu', kernel_regularizer = l2(0.01)))
model.add(BatchNormalization())
model.add(Dropout(0.5)) 
model.add(Dense(64, activation='relu', kernel_regularizer = l2(0.01))) 
model.add(Dropout(0.5))
model.add(Dense(25,activation='sigmoid', kernel_regularizer = l2(0.01))) 
  

model.compile(optimizer='adam',
            loss='binary_crossentropy',
            metrics=['accuracy','top_k_categorical_accuracy'])  
early_stopping = EarlyStopping(monitor = "val_loss", patience = 5, verbose = 1, restore_best_weights = True)
history = model.fit(x_train,y_train,epochs=5,batch_size = 64, validation_data=(x_test,y_test), validation_split = 0.2, callbacks=[early_stopping])
model.summary()
model.evaluate(x_test,y_test,batch_size = 64) 

import sklearn.linear_model as lm
from sklearn.metrics import ConfusionMatrixDisplay, confusion_matrix 
#conf = confusion_matrix(y_test, model.predict(x_test)) 
#ConfusionMatrixDisplay(conf).plot()
#plt.show()

#Display resuslts
epochRange = range(1,6)
plt.plot(epochRange,history.history['accuracy'])
plt.plot(epochRange,history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train','Validation'],loc='best')
plt.show()
plt.plot(epochRange,history.history['loss'])
plt.plot(epochRange,history.history['val_loss'])
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train','Validation'],loc='best')
plt.show() 

#Use the model on a specific input  
img = image.load_img('/kaggle/input/insideouttest/insideout2 movie poster.jpg',target_size=(475,300,3)) 
plt.imshow(img)
img = image.img_to_array(img)
img = img/255.0
img = img.reshape(1,475,300,3)
classes = data.columns[2:]
y_pred = model.predict(img)
top3=np.argsort(y_pred[0])[:-4:-1]
for i in range(3):
  print(classes[top3[i]])
# Out:
# Epoch 1/5
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step - accuracy: 0.0412 - loss: 12.6232 - top_k_categorical_accuracy: 0.2217
# W0000 00:00:1720096205.226598    5446 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# W0000 00:00:1720096207.816299    5444 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 34s 628ms/step - accuracy: 0.0415 - loss: 12.6843 - top_k_categorical_accuracy: 0.2224 - val_accuracy: 0.1800 - val_loss: 9.5738 - val_top_k_categorical_accuracy: 0.5450
# Epoch 2/5
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 260ms/step - accuracy: 0.0789 - loss: 6.9393 - top_k_categorical_accuracy: 0.3081 - val_accuracy: 0.0300 - val_loss: 3.0373 - val_top_k_categorical_accuracy: 0.4500
# Epoch 3/5
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 8s 260ms/step - accuracy: 0.1346 - loss: 2.6750 - top_k_categorical_accuracy: 0.4379 - val_accuracy: 0.1950 - val_loss: 2.1122 - val_top_k_categorical_accuracy: 0.4950
# ...
